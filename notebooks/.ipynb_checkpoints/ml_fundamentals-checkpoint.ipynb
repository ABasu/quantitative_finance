# %%
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

# %%
# Set parameters
data_file = '/Users/anupam/Desktop/AB/DH/quantitative_finance/data/fundamentals.nse/2023-09-01-multigroup.csv'
cols_to_drop = ['Stock Name','BSE code','ISIN','Current Price Rs','Industry Net Profit Growth Annual YoY %','50Day EMA Rs','200Day EMA Rs']

# %%
# Read the raw data and parse into DataFrame
df_raw = pd.read_csv(data_file)
df = df_raw.drop(cols_to_drop, axis=1)

# This step requires much more thought. Ideally we should fill missing values with the industry average
df = df.fillna(0)
df
# Out:
#        NSE code                 Industry Name  PEG TTM PE to Growth  \
# 0        360ONE      Other Financial Services                   2.3
# 1     3IINFOLTD      IT Consulting & Software                  -0.6
# 2       3MINDIA          Industrial Machinery                   1.4
# 3        5PAISA               Capital Markets                   0.1
# 4       63MOONS      IT Consulting & Software                   0.5
# ...         ...                           ...                   ...
# 1178     ZOMATO  Internet Software & Services                  -4.4
# 1179      ZUARI                 Agrochemicals                   0.0
# 1180   ZUARIIND                         Sugar                  -0.9
# 1181  ZYDUSLIFE               Pharmaceuticals                  -0.6
# 1182  ZYDUSWELL                Packaged Foods                  -3.7
#
#       Net Profit Margin Annual %  Operating Profit Margin Annual %  \
# 0                           33.3                              58.5
# 1                            0.2                               4.4
# 2                           11.4                              15.0
# 3                           12.9                              25.3
# 4                           -7.5                              -6.7
# ...                          ...                               ...
# 1178                       -13.7                             -15.6
# 1179                         9.7                               7.1
# 1180                        -7.8                               2.4
# 1181                        11.6                              22.2
# 1182                        13.8                              14.9
#
#       Net Profit Annual YoY Growth %  Revenue Growth Annual YoY %  \
# 0                               13.9                         -0.7
# 1                              102.4                          6.8
# 2                               65.8                         19.4
# 3                              217.2                         13.9
# 4                               69.3                         74.8
# ...                              ...                          ...
# 1178                            19.6                         65.6
# 1179                           265.4                         27.3
# 1180                           954.9                         20.1
# 1181                           -56.3                         12.5
# 1182                             0.5                         11.9
#
#       10Yr High Rs  10Yr price change %  Industry PE TTM  \
# 0            545.0                  0.0             27.7
# 1            119.3                720.0             36.4
# 2          31989.0                945.5             50.3
# 3            580.0                  0.0             22.1
# 4            403.9                193.2             36.4
# ...            ...                  ...              ...
# 1178         169.0                  0.0             51.8
# 1179         690.0                106.5             39.9
# 1180         320.1                167.9             16.6
# 1181         673.7                369.3             38.9
# 1182        2476.8                208.1             67.6
#
#       Long Term Debt To Equity Annual  ROCE Annual 1Yr Ago %  ROCE Annual %  \
# 0                                 2.1                   12.6           12.8
# 1                                 0.0                   -2.9            2.6
# 2                                 0.0                   16.5           35.4
# 3                                 0.0                   10.6           16.6
# 4                                 0.0                   -1.9            2.0
# ...                               ...                    ...            ...
# 1178                              0.0                   -9.1           -4.8
# 1179                              0.4                   15.2           12.2
# 1180                              0.7                    4.4            4.3
# 1181                              0.0                   14.3           16.4
# 1182                              0.0                    6.7            6.2
#
#       Market Capitalization in Cr   MACD  % Distance from 52week high  \
# 0                         17064.4    0.6                         12.4
# 1                           552.6   -0.3                         39.5
# 2                         35147.1  878.4                          2.5
# 3                          1378.6    7.1                          7.2
# 4                          1538.8   24.7                          7.4
# ...                           ...    ...                          ...
# 1178                      83635.2    3.2                          5.5
# 1179                        676.9    1.4                         20.8
# 1180                        428.4   -2.7                         24.2
# 1181                      62144.3    3.5                          8.2
# 1182                      10394.0   41.0                          8.8
#
#       Previous Day RSI   RSI
# 0                 49.3  37.0
# 1                 47.7  47.2
# 2                 72.2  65.8
# 3                 54.2  52.9
# 4                 65.2  66.4
# ...                ...   ...
# 1178              70.0  64.2
# 1179              58.0  55.4
# 1180              39.7  38.6
# 1181              46.9  45.6
# 1182              62.2  64.5
#
# [1183 rows x 18 columns]

# %%
# Normalize the data and parse into vectors and labels
X = normalize(df.iloc[:, 2:])
labels = df.iloc[:,0]
groups = df.iloc[:,1]

# Perform PCA
pca = PCA(n_components=2)
transformed = pca.fit_transform(X)
pca.explained_variance_ratio_
# Out:
# array([0.52966127, 0.30278328])

# %%
df['Industry Name'].nunique()
# Out:
# 116

# %%
x = transformed[:,0]
y = transformed[:,1]


#col_dict = {0:'red', 1:'blue', 2:'green'}
#cols = [col_dict[l] for l in kmeans.labels_]
plt.figure(figsize=(15,10))
plt.scatter(x,y, c='b', s=100, alpha=.5)
for i, l in enumerate(labels):
    plt.text(x[i]+.0003,y[i]-.0001, '{}: {}'.format(targets[i].title(), labels[i]))
for i, c in enumerate(pca.components_.transpose()):
    plt.arrow(0,0, c[0]/50, c[1]/50, alpha=.1, width=.00001)
    plt.text(c[0]/50, c[1]/50, features[i])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Austen and Alcott')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-43049b6d7990> in <module>
#       9 plt.scatter(x,y, c='b', s=100, alpha=.5)
#      10 for i, l in enumerate(labels):
# ---> 11     plt.text(x[i]+.0003,y[i]-.0001, '{}: {}'.format(targets[i].title(), labels[i]))
#      12 for i, c in enumerate(pca.components_.transpose()):
#      13     plt.arrow(0,0, c[0]/50, c[1]/50, alpha=.1, width=.00001)
#
# NameError: name 'targets' is not defined

# %%
X
# Out:
# array([[ 1.34712578e-04,  1.95040384e-03,  3.42638513e-03, ...,
#          7.26276506e-04,  2.88753482e-03,  2.16711538e-03],
#        [-6.48523746e-04,  2.16174582e-04,  4.75584081e-03, ...,
#          4.26944800e-02,  5.15576378e-02,  5.10172014e-02],
#        [ 2.94472736e-05,  2.39784942e-04,  3.15506502e-04, ...,
#          5.25844171e-05,  1.51863796e-03,  1.38402186e-03],
#        ...,
#        [-8.11351203e-04, -7.03171043e-03,  2.16360321e-03, ...,
#          2.18163324e-02,  3.57896031e-02,  3.47979516e-02],
#        [-9.65419763e-06,  1.86647821e-04,  3.57205312e-04, ...,
#          1.31940701e-04,  7.54636448e-04,  7.33719020e-04],
#        [-3.46190598e-04,  1.29119737e-03,  1.39411890e-03, ...,
#          8.23372234e-04,  5.81974465e-03,  6.03494422e-03]])

# %%
d = pd.read_csv('/Users/anupam/Desktop/Server/market_data/TIME_SERIES_DAILY.BSE/3MINDIA.csv')

# %%
# initialize list of lists 
data = [['tom', 10], ['nick', 15], ['juli', 14]] 
  
# Create the pandas DataFrame 
d = pd.DataFrame(data, columns=['Name', 'Age']) 
d.PriceType = 'Unadjusted'

# %%
with open('/Users/anupam/Downloads/test.csv', 'w') as f:
    f.write('#P,Q\n')
    d.to_csv(f)

# %%
d1 = pd.read_csv('/Users/anupam/Downloads/test.csv')

# %%
d1
# Out:
#        #P    Q
# NaN  Name  Age
# 0.0   tom   10
# 1.0  nick   15
# 2.0  juli   14

# %%
a = (2,) #[1,2,3]
print(**a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-e2aa56fb964c> in <module>
#       1 a = (2,) #[1,2,3]
# ----> 2 print(**a)
#
# TypeError: print() argument after ** must be a mapping, not tuple

# %%
def test(**kwargs):
    k, v = kwargs.values()
    print(k)
    #test1()
    
def test1(**kwargs):
    print(kwargs)
    
test(q=12, w="qwer")
# Out:
# dict_values([12, 'qwer'])

# %%
import datapipeline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3b88a8fcdc73> in <module>
# ----> 1 import datapipeline
#
# ~/Desktop/AB/DH/quantitative_finance/lib/datapipeline.py in <module>
#      10
#      11 import datetime, logging, operator, os, re
# ---> 12 import pandas as pd
#      13
#      14 logging.basicConfig(format = '%(funcName)s %(asctime)-25s %(message)s', level = logging.INFO)
#
# /usr/local/lib/python3.9/site-packages/pandas/__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat.numpy import (
#      23     np_version_under1p17 as _np_version_under1p17,
#      24     np_version_under1p18 as _np_version_under1p18,
#
# /usr/local/lib/python3.9/site-packages/pandas/compat/__init__.py in <module>
#      12 import warnings
#      13
# ---> 14 from pandas._typing import F
#      15
#      16 PY38 = sys.version_info >= (3, 8)
#
# /usr/local/lib/python3.9/site-packages/pandas/_typing.py in <module>
#      52 # array-like
#      53
# ---> 54 AnyArrayLike = TypeVar("AnyArrayLike", "ExtensionArray", "Index", "Series", np.ndarray)
#      55 ArrayLike = TypeVar("ArrayLike", "ExtensionArray", np.ndarray)
#      56
#
# AttributeError: module 'numpy' has no attribute 'ndarray'

# %%
dp = DataPipeLineCSV('qw','we')
# Out:
# inspect_error 2023-10-14 22:53:57,506   Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# get_records 2023-10-14 22:53:57,508
# Unfortunately, your original traceback can not be constructed.
#
# inspect_error 2023-10-14 22:53:57,519   Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# get_records 2023-10-14 22:53:57,523
# Unfortunately, your original traceback can not be constructed.
#
# inspect_error 2023-10-14 22:53:57,546   Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# get_records 2023-10-14 22:53:57,550
# Unfortunately, your original traceback can not be constructed.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-88-90f4a38aa437>", line 1, in <module>
#     dp = DataPipeLineCSV('qw','we')
# NameError: name 'DataPipeLineCSV' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 1543, in getinnerframes
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 1501, in getframeinfo
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 709, in getsourcefile
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 738, in getmodule
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 722, in getabsfile
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/posixpath.py", line 380, in abspath
# PermissionError: [Errno 1] Operation not permitted
# ERROR! Session/line number was not unique in database. History logging moved to new session 1182
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-88-90f4a38aa437>", line 1, in <module>
#     dp = DataPipeLineCSV('qw','we')
# NameError: name 'DataPipeLineCSV' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3347, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2056, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 1543, in getinnerframes
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 1501, in getframeinfo
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 709, in getsourcefile
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 738, in getmodule
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 722, in getabsfile
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/posixpath.py", line 380, in abspath
# PermissionError: [Errno 1] Operation not permitted
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-88-90f4a38aa437>", line 1, in <module>
#     dp = DataPipeLineCSV('qw','we')
# NameError: name 'DataPipeLineCSV' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3347, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2056, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2932, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3155, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3366, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2056, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 1543, in getinnerframes
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 1501, in getframeinfo
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 709, in getsourcefile
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 738, in getmodule
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/inspect.py", line 722, in getabsfile
#   File "/usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/posixpath.py", line 380, in abspath
# PermissionError: [Errno 1] Operation not permitted
